# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.append('../smc')

import numpy as np   
import pandas as pd
from tqdm import tqdm
from time import time
import sys


from utils import *     # contains some useful helper functions 
from models import *    # toy models
from solvers import *   # matrix completion solvers
from methods import *

# %%
# Fixed data parameters
max_test_queries = 100            
max_calib_queries = 1000
matrix_generation_seed = 2024    # Data matrix is fixed 

solvers = [
    "pmf", 
    "nnm", 
    "svt"
]

model = "RFM"

n1 = n2 = 200
noise_model = "step"
mu = 15
prop_obs = 0.2
gamma_n = 0.5
gamma_m = 0.9

# Other parameters
verbose = True
allow_inf = False
alpha = 0.1

r=5
k=2
repetition = 2

# %%
#################
# Generate Data #
#################
if model == "RFM":
    mm = RandomFactorizationModel(n1 ,n2, 5)
elif model == "ROM":
    mm = RandomOrthogonalModel(n1 ,n2, 5)
else:
    mm = RandomFactorizationModel(n1 ,n2, 5)

if verbose:
    print('Fixing the ground truth matrix generated from the {} model.\n'.format(model))
    sys.stdout.flush()

U, V, M_true = mm.sample_noiseless(matrix_generation_seed)
# Out:
# Fixing the ground truth matrix generated from the RFM model.

# %%
# Header for results file
def add_header(df):
    df["n1"] = n1
    df["n2"] = n2
    df['alpha'] = alpha
    df['r_true'] = 5
    df['r_guess'] = r
    df['gamma_n'] = gamma_n
    df['gamma_m'] = gamma_m
    df['mu'] = mu
    return df
    

def run_single_experiment(M_true, k, alpha, prop_obs, max_test_queries, max_calib_queries,
                          r, gamma_n=0, gamma_m=0, mu=1, random_state=0):
    res = pd.DataFrame({})


    #-------Generate masks----------#
    #-------------------------------#
    n1, n2 = M_true.shape
    sampler = QuerySampling(n1,n2)
    mask_obs, mask_test = sampler.sample_submask(sub_size=prop_obs, random_state=random_state)
    n_calib_queries = min(int(0.5 * np.sum(np.sum(mask_obs, axis=1) // k)), max_calib_queries)


    #------Sample test queries------#
    #-------------------------------#
    n_test_queries = min(int(0.99 * np.sum(np.sum(mask_test, axis=1) // k)), max_test_queries)
    _, idxs_test, _ = sampler.sample_train_calib(mask_test, k, calib_size=n_test_queries, random_state=random_state)  
    if verbose:
        print("Training size:{}, calib size: {}, test size: {}\n".format(np.sum(mask_obs)-n_calib_queries*k, n_calib_queries, n_test_queries))
        sys.stdout.flush()

    
    #--------Generate noise---------#
    #-------------------------------#
    nm = NoiseModel(random_state)
    M = nm.get_noisy_matrix(M_true, gamma_n=gamma_n, gamma_m=gamma_m, model=noise_model, 
                            mu=mu, alpha=alpha, normalize=False)


    for solver in solvers:
        #------Split train calib--------#
        #-------------------------------#
        mask_train, idxs_calib, _ = sampler.sample_train_calib(mask_obs, k, 
                                    calib_size=n_calib_queries, random_state=random_state)

        #--------Model Training---------#
        #-------------------------------#
        print("Running matrix completion algorithm on the training set...")
        sys.stdout.flush()
        tik = time()
        if solver == "pmf":
            Mhat, _, _ = pmf_solve(M, mask_train, k=r, verbose=verbose, random_state=random_state)
        elif solver == "svt":
            Mhat = svt_solve(M, mask_train, tau=None, verbose = verbose, random_state = random_state)
        elif solver == "nnm":
            Mhat = nnm_solve(M, mask_train, verbose=verbose, random_state=random_state)

        tok=time()
        print(f"run time for {solver} is {tok-tik}.")
        nres = compute_error(M, Mhat, np.ones_like(M)-mask_train)
        print(f"Done training with {solver}! Normalized residual: {nres}\n")
        sys.stdout.flush()
    
    
        #------Compute intervals--------# 
        #-------------------------------#
        ci_method = SimulCI(M, Mhat, mask_obs, idxs_calib, k)
        df = ci_method.get_CI(idxs_test, alpha, allow_inf=allow_inf)
        lower, upper, is_inf= df.loc[0].lower, df.loc[0].upper, df.loc[0].is_inf
        tmp_res = evaluate_SCI(lower, upper, k, M, idxs_test, is_inf=is_inf, method="conformal")
        tmp_res['solver'] = solver
        tmp_res['normalized_residual'] = nres
        tmp_res['solver_runtime'] = tok-tik 
        res = pd.concat([res, tmp_res])

    res['k'] = k     
    res['Calib_queries'] = n_calib_queries
    res['Train_entries'] = np.sum(mask_train)
    res['Test_queries'] = n_test_queries
    res['random_state'] = random_state
    return res

# %%
seed = 1 

#####################
#  Run Experiments  #
#####################
results = pd.DataFrame({})

for i in tqdm(range(1, repetition+1), desc="Repetitions", leave=True, position=0):
    random_state = repetition * (seed-1) + i
    
    res = run_single_experiment(M_true, k, alpha, prop_obs, max_test_queries, max_calib_queries,
                        r, gamma_n=gamma_n, gamma_m=gamma_m, mu=mu, random_state=random_state)
    
    results = pd.concat([results, res])

add_header(results)
# Out:
# k:   0%|                                                                                         | 0/1 [00:00<?, ?it/s]
# Training size:6000, calib size: 1000, test size: 100
#
# Running matrix completion algorithm on the training set...
# Iteration: 1; Mean diff: 0.0140
# Iteration: 2; Mean diff: 0.0060
# Iteration: 3; Mean diff: 0.0038
# Iteration: 4; Mean diff: 0.0031
# Iteration: 5; Mean diff: 0.0028
# Iteration: 6; Mean diff: 0.0025
# Iteration: 7; Mean diff: 0.0017
# Iteration: 8; Mean diff: 0.0012
# Iteration: 9; Mean diff: 0.0011
# Iteration: 10; Mean diff: 0.0010
# Iteration: 11; Mean diff: 0.0009
# Iteration: 12; Mean diff: 0.0008
# Iteration: 13; Mean diff: 0.0008
# Iteration: 14; Mean diff: 0.0008
# Iteration: 15; Mean diff: 0.0007
# Iteration: 16; Mean diff: 0.0007
# Iteration: 17; Mean diff: 0.0007
# Iteration: 18; Mean diff: 0.0007
# Iteration: 19; Mean diff: 0.0007
# Iteration: 20; Mean diff: 0.0006
# Iteration: 21; Mean diff: 0.0005
# Iteration: 22; Mean diff: 0.0004
# Iteration: 23; Mean diff: 0.0003
# Iteration: 24; Mean diff: 0.0003
# Iteration: 25; Mean diff: 0.0003
# Iteration: 26; Mean diff: 0.0002
# Iteration: 27; Mean diff: 0.0002
# Iteration: 28; Mean diff: 0.0002
# Iteration: 29; Mean diff: 0.0001
# Iteration: 30; Mean diff: 0.0001
# Iteration: 31; Mean diff: 0.0001
# Iteration: 32; Mean diff: 0.0001
# Iteration: 33; Mean diff: 0.0001
# Iteration: 34; Mean diff: 0.0001
# Iteration: 35; Mean diff: 0.0000
# Iteration: 36; Mean diff: 0.0000
# Iteration: 37; Mean diff: 0.0000
PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Oct 24 05:03:32 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 24 05:03:32 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 24 05:03:32 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 24 05:03:32 PM: Applying reduction SCS
# (CVXPY) Oct 24 05:03:32 PM: Finished problem compilation (took 2.797e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 24 05:03:32 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.7 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 120200, constraints m: 200200
# cones: 	  l: linear vars: 120000
# 	  s: psd vars: 80200, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 500, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 212200, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.77e+01  1.46e+00  4.58e+03 -5.40e+02  1.00e-01  5.98e-01
#    250| 7.65e-03  3.65e-05  3.52e-04  8.23e+02  2.85e-02  1.17e+02
#    500| 2.99e-03  2.72e-06  4.34e-04  8.23e+02  2.85e-02  2.39e+02
# ------------------------------------------------------------------
# status:  solved (inaccurate - reached max_iters)
# timings: total: 2.39e+02s = setup: 1.47e-01s + solve: 2.39e+02s
# 	 lin-sys: 2.40e+00s, cones: 2.35e+02s, accel: 2.56e-01s
# ------------------------------------------------------------------
# objective = 823.313469 (inaccurate)
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 24 05:07:31 PM: Problem status: optimal_inaccurate
# (CVXPY) Oct 24 05:07:31 PM: Optimal value: 8.234e+02
# (CVXPY) Oct 24 05:07:31 PM: Compilation took 2.797e-01 seconds
# (CVXPY) Oct 24 05:07:31 PM: Solver (including time spent in interface) took 2.388e+02 seconds
# run time for nnm is 239.1121802330017.
# Done training with nnm! Normalized residual: 0.2290498744791797
#
# Computing conformal prediction intervals for 100 test queries...
# C:\Users\liang\anaconda3\envs\scmc\lib\site-packages\cvxpy\problems\problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# CI: 100%|████████████████████████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 33.20it/s]
# Done!
# Running matrix completion algorithm on the training set...
# Iteration: 1; Rel error: 1.0000
# Iteration: 11; Rel error: 0.5982
# Iteration: 21; Rel error: 0.5723
# Iteration: 31; Rel error: 0.5314
# Iteration: 41; Rel error: 0.6529
# Iteration: 51; Rel error: 0.7027
# Iteration: 61; Rel error: 0.5502
# Iteration: 71; Rel error: 0.5020
# Iteration: 81; Rel error: 0.4845
# Iteration: 91; Rel error: 0.4787
# Iteration: 101; Rel error: 0.6052
# Iteration: 111; Rel error: 0.5745
# Iteration: 121; Rel error: 0.6142
# Iteration: 131; Rel error: 0.4319
# Iteration: 141; Rel error: 0.5722
# Iteration: 151; Rel error: 0.6216
# Iteration: 161; Rel error: 0.4554
# Iteration: 171; Rel error: 0.4927
# Iteration: 181; Rel error: 0.5648
# Iteration: 191; Rel error: 0.6671
# Iteration: 201; Rel error: 0.4768
# Iteration: 211; Rel error: 0.5075
# Iteration: 221; Rel error: 0.6254
# Iteration: 231; Rel error: 0.6532
# Iteration: 241; Rel error: 0.4741
# Iteration: 251; Rel error: 0.8310
# Iteration: 261; Rel error: 0.6003
# Iteration: 271; Rel error: 0.7617
# Iteration: 281; Rel error: 0.4731
# Iteration: 291; Rel error: 0.5124
# Iteration: 301; Rel error: 0.5327
# Iteration: 311; Rel error: 0.5462
# Iteration: 321; Rel error: 0.5971
# Iteration: 331; Rel error: 0.6446
# Iteration: 341; Rel error: 0.6619
# Iteration: 351; Rel error: 0.7421
# Iteration: 361; Rel error: 0.5744
# Iteration: 371; Rel error: 0.7467
# Iteration: 381; Rel error: 0.6053
# Iteration: 53; Mean diff: 0.0000
# Iteration: 54; Mean diff: 0.0000
# Iteration: 55; Mean diff: 0.0000
# Iteration: 56; Mean diff: 0.0000
# Iteration: 57; Mean diff: 0.0000
# Iteration: 58; Mean diff: 0.0000
# Iteration: 59; Mean diff: 0.0000
# Iteration: 60; Mean diff: 0.0000
# Iteration: 61; Mean diff: 0.0000
# Iteration: 62; Mean diff: 0.0000
# Iteration: 63; Mean diff: 0.0000
# Iteration: 64; Mean diff: 0.0000
# Iteration: 65; Mean diff: 0.0000
# Iteration: 66; Mean diff: 0.0000
# Iteration: 67; Mean diff: 0.0000
# Stopping criteria met, training terminated.
# run time for pmf is 13.106388330459595.
# Done training with pmf! Normalized residual: 0.40479878995284274
#
# Computing conformal prediction intervals for 100 test queries...
# CI: 100%|████████████████████████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 29.23it/s]
# Done!
# Running matrix completion algorithm on the training set...
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Oct 24 05:09:46 PM: Your problem has 40000 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 24 05:09:46 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 24 05:09:46 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 24 05:09:46 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 24 05:09:46 PM: Compiling problem (target solver=SCS).
# (CVXPY) Oct 24 05:09:46 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Oct 24 05:09:46 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 24 05:09:46 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 24 05:09:46 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 24 05:09:46 PM: Applying reduction SCS
# (CVXPY) Oct 24 05:09:46 PM: Finished problem compilation (took 2.662e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 24 05:09:46 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.7 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 120200, constraints m: 200200
# cones: 	  l: linear vars: 120000
# 	  s: psd vars: 80200, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 500, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 212200, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.71e+01  1.42e+00  4.25e+03 -7.06e+02  1.00e-01  6.40e-01
#    250| 9.78e-03  5.39e-05  1.03e-04  7.81e+02  2.59e-02  1.35e+02
#    500| 2.51e-03  4.53e-06  4.26e-04  7.82e+02  2.59e-02  2.77e+02
# ------------------------------------------------------------------
# status:  solved (inaccurate - reached max_iters)
# timings: total: 2.77e+02s = setup: 1.50e-01s + solve: 2.76e+02s
# 	 lin-sys: 2.57e+00s, cones: 2.73e+02s, accel: 2.67e-01s
# ------------------------------------------------------------------
# objective = 781.509827 (inaccurate)
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 24 05:14:23 PM: Problem status: optimal_inaccurate
# (CVXPY) Oct 24 05:14:23 PM: Optimal value: 7.816e+02
# (CVXPY) Oct 24 05:14:23 PM: Compilation took 2.662e-01 seconds
# (CVXPY) Oct 24 05:14:23 PM: Solver (including time spent in interface) took 2.766e+02 seconds
# run time for nnm is 276.8818941116333.
# Done training with nnm! Normalized residual: 0.2424746511175049
#
# Computing conformal prediction intervals for 100 test queries...
# C:\Users\liang\anaconda3\envs\scmc\lib\site-packages\cvxpy\problems\problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# CI: 100%|████████████████████████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 31.38it/s]
# Done!
# Running matrix completion algorithm on the training set...
# Iteration: 1; Rel error: 1.0000
# Iteration: 11; Rel error: 0.6475
# Iteration: 21; Rel error: 1.0490
# Iteration: 31; Rel error: 0.8348
# Iteration: 41; Rel error: 0.8783
# Iteration: 51; Rel error: 0.7220
# Iteration: 61; Rel error: 0.6708
# Iteration: 71; Rel error: 0.6558
# Iteration: 81; Rel error: 0.8922
# Iteration: 91; Rel error: 0.5858
# Iteration: 101; Rel error: 0.6894
# Iteration: 111; Rel error: 0.9006
# Iteration: 121; Rel error: 0.6235
# Iteration: 131; Rel error: 0.5885
# Iteration: 141; Rel error: 0.7115
# Iteration: 151; Rel error: 0.7190
# Iteration: 161; Rel error: 0.6357
# Iteration: 171; Rel error: 0.6467
# Iteration: 181; Rel error: 0.6951
# Iteration: 191; Rel error: 0.7562
# Iteration: 201; Rel error: 0.6734
# Iteration: 211; Rel error: 0.6736
# Iteration: 221; Rel error: 0.6047
# Iteration: 231; Rel error: 0.6030
# Iteration: 241; Rel error: 0.6887
# Iteration: 251; Rel error: 0.6408
# Iteration: 261; Rel error: 0.6894
# Iteration: 271; Rel error: 0.5686
# Iteration: 281; Rel error: 0.6942
# Iteration: 291; Rel error: 0.5342
# Iteration: 301; Rel error: 0.6930
# Iteration: 311; Rel error: 0.6104
# Iteration: 321; Rel error: 0.7821
# Iteration: 331; Rel error: 0.7742
# Iteration: 341; Rel error: 0.5777
# Iteration: 351; Rel error: 0.7714
# Iteration: 361; Rel error: 0.5346
# Iteration: 371; Rel error: 0.5709
# Iteration: 381; Rel error: 0.7553
# Iteration: 391; Rel error: 0.8871
# Iteration: 401; Rel error: 0.7272
# Iteration: 411; Rel error: 0.5061
# Iteration: 421; Rel error: 0.6254
# Iteration: 431; Rel error: 0.6638
# Iteration: 441; Rel error: 0.9942
# Iteration: 451; Rel error: 0.7774
# Iteration: 461; Rel error: 0.4970
# Iteration: 471; Rel error: 0.7548
# Iteration: 481; Rel error: 0.8248
# Iteration: 491; Rel error: 0.6146
# run time for svt is 114.31218314170837.
# Done training with svt! Normalized residual: 0.45354588661509904
#
# Computing conformal prediction intervals for 100 test queries...
# CI: 100%|████████████████████████████████████████████████████████████████████████████| 100/100 [00:02<00:00, 34.79it/s]
# Done!
# k: 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [07:00<00:00, 420.54s/it]
# Repetitions: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [13:18<00:00, 399.10s/it]
#    Query_coverage  Coverage      Size  Inf_prop     Method solver      nres  \
# 0            0.91     0.950  2.576986       0.0  conformal    pmf  0.399003
# 0            0.84     0.900  1.134601       0.0  conformal    nnm  0.229050
# 0            0.86     0.905  2.382569       0.0  conformal    svt  0.470796
# 0            0.87     0.935  2.310878       0.0  conformal    pmf  0.404799
# 0            0.93     0.945  1.047008       0.0  conformal    nnm  0.242475
# 0            0.92     0.945  1.876785       0.0  conformal    svt  0.453546
#
#    solver_runtime  k  Calib_queries  Train_entries  Test_queries  \
# 0       17.001421  2           1000           6000           100
# 0      239.112180  2           1000           6000           100
# 0      105.973020  2           1000           6000           100
# 0       13.106388  2           1000           6000           100
# 0      276.881894  2           1000           6000           100
# 0      114.312183  2           1000           6000           100
#
#    random_state   n1   n2  alpha  r  gamma_n  gamma_m  mu
# 0             1  200  200    0.1  5      0.5      0.9  15
# 0             1  200  200    0.1  5      0.5      0.9  15
# 0             1  200  200    0.1  5      0.5      0.9  15
# 0             2  200  200    0.1  5      0.5      0.9  15
# 0             2  200  200    0.1  5      0.5      0.9  15
# 0             2  200  200    0.1  5      0.5      0.9  15
